# %% [markdown]
# # List of Imports

# %%
import pandas as pd
import ast
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %% [markdown]
# # Loading Data

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')
 
movies = movies.drop(columns=[
    'budget', 'homepage', 'original_title', 'status',
    'production_companies', 'production_countries',
    'tagline', 'spoken_languages', 'vote_average'
])

# %% [markdown]
# ### Merge & Cleaning the data set

# %%
movies = movies.merge(credits, on='title')
movies = movies.drop(columns=['vote_count', 'movie_id'])
movies.dropna(inplace=True)

# %% [markdown]
# ## Helper functions

# %%
def extract_cast_names(obj):
    """Extract top 3 cast names from JSON string."""
    if pd.isna(obj):
        return []
    l, counter = [], 0
    for i in ast.literal_eval(obj):
        if counter == 3:
            return l
        l.append(i['name'])
        counter += 1
    return l
 
 
def extract_director_names(obj):
    """Extract director name(s) from crew JSON string."""
    if pd.isna(obj):
        return []
    return [i['name'] for i in ast.literal_eval(obj) if i['job'] == 'Director']
 
 
def rem_spaces(lst):
    """Remove spaces from strings in a list."""
    if not isinstance(lst, list):
        return []
    return [i.replace(' ', '') for i in lst]

# %% [markdown]
# # Performing feature engineering

# %%
movies['cast']     = movies['cast'].apply(extract_cast_names)
movies['crew']     = movies['crew'].apply(extract_director_names)
movies['keywords'] = movies['keywords'].apply(extract_cast_names)
movies['genres']   = movies['genres'].apply(extract_cast_names)
movies['overview'] = movies['overview'].apply(lambda x: x.split())
 
movies['tags'] = movies['overview'] + movies['genres'] + movies['cast'] + movies['crew']
 
df = movies[['id', 'title', 'tags']].copy()
df['tags'] = df['tags'].apply(lambda x: ' '.join(x))

# %% [markdown]
# # What is Stemming

# %%
ps = PorterStemmer()
 
def stem(text):
    return ' '.join([ps.stem(word) for word in text.split()])
 
df['tags'] = df['tags'].apply(stem).apply(lambda x: x.lower())

# %% [markdown]
# # Vectorisation & Similarity
# **count vectorizer** to convert text to vectors, max_features limits the number of features to 5000, stop_words removes common English words
# words like I, the, and etc. which do not add much meaning to the text

# %%
cv = CountVectorizer(max_features=5000, stop_words='english') 
vectors = cv.fit_transform(df['tags']).toarray()
 
similarity = cosine_similarity(vectors)
 
print(f"Vocabulary size : {len(cv.get_feature_names_out())}")
print(f"Similarity shape: {similarity.shape}")
# Out:
# Vocabulary size : 5000
# Similarity shape: (4805, 4805)

# %% [markdown]
# # Recomendation
# #### here we calculate the sortest distance between the given movie and all other movies in the dataset,
# #### and return the top 5 movies with the highest similarity score

# %%
# here we calculate the sortest distance between the given movie and all other movies in the dataset,
# and return the top 5 movies with the highest similarity score.
def recommend(movie):
    """Print top 5 movies similar to the given movie."""
    if movie not in df['title'].values:
        print('Movie not found in dataset.')
        return
 
    movie_idx   = df[df['title'] == movie].index[0]
    distances   = similarity[movie_idx]
    movies_list = sorted(enumerate(distances), key=lambda x: x[1], reverse=True)[1:6]
 
    print(f'\nMovies similar to "{movie}":')
    for i in movies_list:
        print(f"  - {df.iloc[i[0]]['title']}")
 
 
recommend('Batman')
# Out:
# Movies similar to "Batman":
#   - Batman
#   - The R.M.
#   - Big Fish
#   - Curse of the Golden Flower
#   - Code of Honor

# %% [markdown]
# # creating Pickle file so that we can show the results

# %%
pickle.dump(df,open('movies.pkl','wb'))
pickle.dump(similarity, open('similarity.pkl','wb'))
print('\nSaved: movies.pkl, similarity.pkl')
# Out:
# Saved: movies.pkl, similarity.pkl

# %% [markdown]
# ## Why create a .pkl file ?
# **The problem without .pkl files :-**
# Every time you run the app, Python would have to redo all the heavy work — reading CSVs, processing text, stemming 4800+ movies, building the 4800×5000 vector matrix, and computing the full cosine similarity matrix. That can take 30–60 seconds each run.
#
# **What .pkl (Pickle) does :-**
#         It serializes Python objects — meaning it converts them into a binary file saved on disk. When you need them again, you just load the file and the objects are instantly ready in memory, exactly as they were.
